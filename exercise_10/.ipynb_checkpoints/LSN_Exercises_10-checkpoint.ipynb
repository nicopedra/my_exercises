# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 10</span>

# %% [markdown]
# ### ex
# Nella cartella ex è presente l'implementazione del codice relativo alla prima parte della decima esercitazione.
# Questa esercitazione ha lo stesso obbiettivo della precedente: trovare il minimo cammino date delle città che si voglio visitare (il problema del commesso viaggiatore).
# Ma per questa parte utilizzeremo il metodo del **Simulated Annealing**.
# La struttura iniziale del codice è la medesima di quella della scorsa esercitazione. All'inizio del main viene definita la parola $\texttt{square}$. Se definita si cerca il percorso minimo per città poste all'interno di un quadrato, altrimenti per città poste su di una circonferenza.
# **nota** ho usato le stesse coordinate della nona esercitazione, infatti nei grafici sovrappongo i cammini trovati per effettivamente confrontare i risultati.
# Successivamente ho scelto il range di temperature: semplicemente partendo da una temperatura iniziale pari a $100000$, e le altre ottenendole dividendo a metà quella precedente.. così via. In totale ho guardato $40$ temperature.
# Per ogni temperatura viene utilizzato il metodo di Metropolis:
# - vengono eseguiti $N$ step MC, per ogni step viene proposto un nuovo percorso (tramite mutazione, la stessa usata per l'algoritmo generico) e viene ricavata la probabilità di scelta $p = e^{-\beta( L_{new}-L_{old} ) }$, dove $L_{new}$ e $L_{old}$ sono la lunghezza dei cammini per il percorso proposto e il percorso vecchio.
#
# **nel codice**
# Concretamente nel codice chiamo per ogni temperatura la funzione $\texttt{single_MC_SA}$ che prende come argomenti:
# - generatore random
# - temperatura inversa
# - numero di step MC
# - cammino attuale

# %% [markdown]
# ### Exercise 10.1
#
# By adapting your Genetic Algorithm (GA) code, developed during the Numerical Exercise 9, write a C++ code to solve the TSP with a **Simulated Annealing** (SA) algorithm. Apply your code to the optimization of a path among
#
# - 32 cities randomly placed on a circumference
# - 32 cities randomly placed inside a square
#
# Show your results via:
#
# - a picture of the length of the best path as a function of the iteration of your algorithm
# - a picture of the best path
#
# and compare your SA results with those obtained with GA in the previosu numerical exercise.

# %% [markdown]
# ## CIRCUMFERENCE
# Ho usato un range di 40 temperature, per ogni temperatura ho compito 500 step MC e ogni 10 step stampo quanto vale la cost function. Inoltre mostro anche un grafico di come varia la cost function al termine di ogni simulazione con temperatura fissa.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


folder = "circumference/","square/"
name = "beta_path.txt","best_path.txt","picture_path.txt"
ylab = "$L^{(2)}$, beta","$L^{(2)}$","y"
title =  "Best Path cost function, beta","Best Path cost function","Best Path"
xlabel = "$beta$ ,inverse temperature","iterations"

fig,axs = plt.subplots(nrows=1,ncols=3,figsize=(15, 5))

for i in range(3):
    if i != 2:
        it = np.loadtxt(folder[0]+name[i],usecols=(0),unpack='true')
        y = np.loadtxt(folder[0]+name[i],usecols=(1),unpack='true')
        axs[i].plot(it,y)
        axs[i].set_xlabel(xlabel[i])
    else:
        x = np.loadtxt(folder[0]+name[i],usecols=(1),unpack='true')
        y = np.loadtxt(folder[0]+name[i],usecols=(2),unpack='true')
        n = np.loadtxt(folder[0]+name[i],dtype='int',usecols=(0),unpack='true')
        axs[i].plot(x,y,"--o",color='b')
        axs[i].set_xlabel("x")
        for xs,ys,ns in zip(x,y,n):
            label = f"{ns}"
            plt.annotate(label,(xs,ys),textcoords="offset points",xytext=(0,10),ha='center')
        x = np.loadtxt(folder[0]+"circumference_GA/"+name[i],usecols=(1),unpack='true')
        y = np.loadtxt(folder[0]+"circumference_GA/"+name[i],usecols=(2),unpack='true')
        axs[i].plot(x,y,"--o",alpha=0.5,color='red')
        plt.legend(["SA","single GA"])
    axs[i].set_ylabel(ylab[i])
    axs[i].set_title(title[i])

plt.show()

# %% [markdown]
# ## SQUARE
# Ho usato un range di 40 temperature, per ogni temperatura ho compito 500 step MC e ogni 10 step stampo quanto vale la cost function. Inoltre mostro anche un grafico di come varia la cost function al termine di ogni simulazione con temperatura fissa

# %%
fig,axs = plt.subplots(nrows=1,ncols=3,figsize=(15, 5))

for i in range(3):
    if i != 2:
        it = np.loadtxt(folder[1]+name[i],usecols=(0),unpack='true')
        y = np.loadtxt(folder[1]+name[i],usecols=(1),unpack='true')
        axs[i].plot(it,y)
        axs[i].set_xlabel(xlabel[i])
    else:
        x = np.loadtxt(folder[1]+name[i],usecols=(1),unpack='true')
        y = np.loadtxt(folder[1]+name[i],usecols=(2),unpack='true')
        n = np.loadtxt(folder[1]+name[i],dtype='int',usecols=(0),unpack='true')
        axs[i].plot(x,y,"--s")
        axs[i].set_xlabel("x")
        for xs,ys,ns in zip(x,y,n):
            label = f"{ns}"
            plt.annotate(label,(xs,ys),textcoords="offset points",xytext=(0,10),ha='center')
        x = np.loadtxt(folder[1]+"square_GA/"+name[i],usecols=(1),unpack='true')
        y = np.loadtxt(folder[1]+"square_GA/"+name[i],usecols=(2),unpack='true')
        axs[i].plot(x,y,"--s",alpha=0.5,color='r')
        plt.legend(["SA","single GA"])
    axs[i].set_ylabel(ylab[i])
    axs[i].set_title(title[i])
    
    
plt.show()

# %% [markdown]
# #### COMMENTO
#
# È interessante notare l'andamento del cammino in funzione degli step. All'inizio il suo valore oscilla attorno a valori che non sono assolutamente il minimo. Ma stiamo guardando ad alte temperature. Per cui le mosse proposte vengono accettate molto più frequentemente.

# %% [markdown]
# ### Exercise 10.2
#
# Parallelize with MPI libraries your Genetic Algorithm code in order to solve the TSP by performing a *Genetic Search* with 4 **parallel GA searches of the optimal path**:
# each node should perform an independent GA search the so-called *Continents*, **but** every $N_{migr}$ generations the *Continents* should exchange their best individuals randomly.
# Apply your code to the TSP problem for 32 cities randomly placed inside a square and try to estimate if your performances improve with *Continents*.

# %% [markdown]
# ### parallel_GA
#
# Nella cartella parallel_GA è presente l'implementazione del codice relativo alla seconda parte dell'esercitazione.
# Questa seconda parte consiste nell'implementare l'algoritmo genetico per trovare il minimo cammino tra le città (esattamente lo stesso obbiettivo della nona esercitazione e della prima parte di questa esercitazione) ma parallelamente.
#
# ** strumento --> MPI **
# MPI sta per $\texttt{Message Passing Interface}$. Il programma viene eseguito seguendo il modello ** SPMD **($\texttt{Single Program Multiple Data}$), significa semplicemente che tuttò ciò che viene scritto tra i comandi $\texttt{MPI_Init}$ e $\texttt{MPI_Finalize}$ viene eseguito da tutti i nodi senza che essi comunichino.. a meno che non si vada esplicitamente a chiamare una *comunicazione* tra loro.
# **nota** prima di poter lanciare e scrivere un codice con MPI occorre ricordarsi di caricare il modulo MPI e compilare ed eseguire nel modo corretto (non mi soffermo di più su questo).
#
# ### DETTAGLIO
# Ho utilizzato la stessa classe implementata per l'esercitazione $9$. leggermente modificata.
#
# classe $\texttt{Population}$, **elementi privati** sono:
# -  $\texttt{size}$ grandezza della popolazione
# - $\texttt{genes}$ quanti geni per singolo cromosoma (il numero di città in questo caso)
# - $\texttt{vector<vector<int>>}$ $\texttt{chromosomes}$ il vettore contenente tutta la popolazione, un singolo elemento della popolazione è un cromosoma composto da $\texttt{genes}$ geni
# - $\texttt{p}_m$,$\texttt{p}_c$ probabilità di mutazione e di crossover
# - $\texttt{father}$,$\texttt{mother}$ indice in cui salvare padre e madre scelti per un possibile crossover
# - $\texttt{taglio}$ indice necessario al crossover (posto a metà in questo caso)
# - $\texttt{vector<int>}$ $\texttt{start_chromo}$ per riempire la popolazione iniziale e per la $\texttt{check function}$
# - $\texttt{vector<int>}$ $\texttt{new_child_one}$ e $\texttt{new_child_two}$ per la generazione dei due nuovi figli dopo un possibile crossover
# - $\texttt{vector<double>}$ $\texttt{fitness}$ per il metodo di selezione
# - $\texttt{vector<vector<int>>}$ $\texttt{the_BigFour}$ usato per salvare alla fine i migliori quattro cammini, diventa utile sono per il nodo $0$
# - generatore random $\texttt{Random}$ $\texttt{rnd}$
#
# mentre i **metodi** principali della classe sono:
# - $\texttt{fill_initial_population}$ questo metodo prende come argomento il rank del nodo e utilizza il cromosoma $\texttt{start_chromo}$ per generare tanti cromosomi quanto è la grandezza della popolazione, utilizzando la funzione shuffle della libreria standard (che mescola gli elementi di un vettore generando quindi una permutazione). Prima di riempire la popolazione viene inizializzato il generatore random (elemento privato della classe) facendogli leggere un certo seme in base al rank del nodo. In questo modo ogni nodo possiede un generatore random con seme diverso, per cui per ciascun nodo la sequenza di numeri casuali generati è diversa.
# - $\texttt{mutation}$ metodo che prende come argomento un cromosoma ed effettua su di esso una mutazione (secondo una certa probabilità $\texttt{p}_m$). Ho implementato $4$ diverse mutazioni:
#     - shuffle (stessa funzione citata sopra)
#     - semplice scambio di due città adiacenti
#     - inversione di percorso scegliendo in modo casuale indice iniziale e finale
#     - shift di un numero di elementi, scegliendo in modo casuale quanti elementi shiftare e di quanto
# - $\texttt{selection}$ metodo che seleziona padre e madre per il crossover. Come:
#     - ad ogni cromosoma viene associata una probabilità di essere scelto. Tale probabilità l'ho definita come: $p_i = \dfrac{fitness_i}{\sum_k^{size} fitness_k}$ dove $fitness_i = \dfrac{1}{L_i^{(2)}}$
#     - si entra in un ciclo infinito
#     - viene generato un numero $r$ casuale in modo uniforme in $[0,1]$
#     - si sceglie in modo random un elemento $i$ della popolazione e si verifica se $r < p_i$. Se ciò è verificato allora $i$ è un genitore e si esce dal ciclo, altrimenti si continua finche non viene trovato un genitore. (questo intero procedimento è eseguito due volte perchè mi servono due genitori)
# - $\texttt{order_chrom}$ ordina in modo decrescente rispetto alla $L^{(2)}$ la mia popolazione di cromosomi
# - $\texttt{crossover}$ effettua il crossover (con probabilità $p_c$) generando due nuovi figli
# - $\texttt{update}$ se il crossover è avvenuto allora si aggiorna la popolazione:
#     - si aggiungono i figli alla popolazione
#     - si ordina la popolazione
#     - si eliminano gli ultimi due elementi della popolazione
# - $\texttt{scambio}$ scambia il contenuto del cammino migliore della popolazione con il contenuto del cammino che gli viene dato come argomento
# - $\texttt{best_list}$ semplicemente salva in Big_Four il percorso che prende come argomento
#
# La struttura del main è praticamente identica a quella utilizzata per l'esercitazione $9$, con due differenze importanti:
# 1. all'inizio del main viene dichiarato un generatore random con un certo seme (che ovviamente resta fisso durante tutta la simulazione) quindi uguale per tutti i nodi. Tale seme è scelto in modo tale da produrre lo stesso percorso utilizzato per la scorsa esercitazione e per la prima parte di questa, in modo poi da confrontare i risultati. Inoltre essendo per tutti i nodi lo stesso generatore questo significa che la sequenza generata è la medesima. Per cui mi sono avvalso dell'utilizzo di questo generatore per decidere quali nodi debbano scambiarsi il migliore.
# 2. definisco allora la seconda differenza per essere più chiaro:
#     - ogni tot step $\texttt{N_{migr}}$ due nodi scelti in modo Random si scambiano il miglior elemento della popolazione. Per evitare incomprensioni tra nodi per decidere chi dovesse scambiarsi il migliore mi sono avvalso dell'utilizzo del generatore comune a tutti (così per tutti i nodi le variabili chiamate nel codice $\texttt{rank_a}$ e $\texttt{rank_b}$ sono le medesime)
#     - la scambio avviene utilizzando le funzioni di $\texttt{MPI}$ $\texttt{MPI_Send}$ e $\texttt{MPI_Recv}$. Esempio: il nodo $\texttt{a}$ manda al nodo $\texttt{b}$ il suo miglior elemento ($\texttt{MPI_Send}$), il nodo $\texttt{b}$ si prepara a riceverlo ($\texttt{MPI_Recv}$). Allo stesso tempo fanno il viceversa (è stato ovviamente necessario utilizzare viariabili di appoggio, che poi sostituiscono il valore del migliore precedente con il nuovo arrivato).
#
# Nell'ultima parte del main ciascun nodo manda il suo miglior cammino al nodo $0$ che poi si occupa di stampare il migliore di tutti.

# %% [markdown]
# ## CIRCUMFERENCE
# Per ogni nodo sono stati compiuti 15'000 step (ricordo che per GA non parallelo ho usato 50'000 iterazioni)
# Parametri utilizzati:
# - population size = cities (32)
# - $p_m = 0.2$ (come GA non parallelo)
# - $p_c = 0.7$  (come GA non parallelo)
# - $N_{migr} = 200$

# %%
x = np.loadtxt("parallel_GA/"+folder[0]+"picture_final_path.txt",usecols=(1),unpack='true')
y = np.loadtxt("parallel_GA/"+folder[0]+"picture_final_path.txt",usecols=(2),unpack='true')
n = np.loadtxt("parallel_GA/"+folder[0]+"picture_final_path.txt",dtype='int',usecols=(0),unpack='true')
plt.plot(x,y,"--s")
plt.xlabel("x")
plt.ylabel("y")
for xs,ys,ns in zip(x,y,n):
    label = f"{ns}"
    plt.annotate(label,(xs,ys),textcoords="offset points",xytext=(0,10),ha='center')
x = np.loadtxt(folder[0]+"circumference_GA/"+"picture_path.txt",usecols=(1),unpack='true')
y = np.loadtxt(folder[0]+"circumference_GA/"+"picture_path.txt",usecols=(2),unpack='true')
plt.plot(x,y,"--s",alpha=0.5,color='r')
plt.legend(["parallel GA","single GA"])

time = np.loadtxt("parallel_GA/"+folder[0]+"parallel_GA_circumference.time",usecols=(0),unpack='true')
print("execution time T_4: ",time ," sec")
time1 = np.loadtxt("parallel_GA/"+folder[0]+"circumference.time",usecols=(0),unpack='true')

C_4 = 4*time
S_4 = time1/time
E_4 = time1/C_4

print("cost = ", C_4)
print("SpeedUp = ",S_4)
print("Efficiency = ",E_4)

plt.show()
# Out:
# execution time T_4:  2.27165  sec
# cost =  9.0866
# SpeedUp =  2.454414192327163
# Efficiency =  0.6136035480817907

# %% [markdown]
# ## SQUARE
# Per ogni nodo sono stati compiuti 20'000 step (ricordo che per GA non parallelo ho usato 50'000 iterazioni)
# Parametri utilizzati:
# - population size = cities (32)
# - $p_m = 0.2$ (come GA non parallelo)
# - $p_c = 0.7$  (come GA non parallelo)
# - $N_{migr} = 200$

# %%
x = np.loadtxt("parallel_GA/"+folder[1]+"picture_final_path.txt",usecols=(1),unpack='true')
y = np.loadtxt("parallel_GA/"+folder[1]+"picture_final_path.txt",usecols=(2),unpack='true')
n = np.loadtxt("parallel_GA/"+folder[1]+"picture_final_path.txt",dtype='int',usecols=(0),unpack='true')
plt.plot(x,y,"--s")
plt.xlabel("x")
plt.ylabel("y")
for xs,ys,ns in zip(x,y,n):
    label = f"{ns}"
    plt.annotate(label,(xs,ys),textcoords="offset points",xytext=(0,10),ha='center')
x = np.loadtxt(folder[1]+"square_GA/"+"picture_path.txt",usecols=(1),unpack='true')
y = np.loadtxt(folder[1]+"square_GA/"+"picture_path.txt",usecols=(2),unpack='true')
plt.plot(x,y,"--s",alpha=0.5,color='r')
plt.legend(["parallel GA","single GA"])

time = np.loadtxt("parallel_GA/"+folder[1]+"parallel_GA_square.time",usecols=(0),unpack='true')
print("execution time: ",time ," sec")
time1 = np.loadtxt("parallel_GA/"+folder[1]+"square.time",usecols=(0),unpack='true')

C_4 = 4*time
S_4 = time1/time
E_4 = time1/C_4

print("cost = ", C_4)
print("SpeedUp = ",S_4)
print("Efficiency = ",E_4)

plt.show()
# Out:
# execution time:  2.96146  sec
# cost =  11.84584
# SpeedUp =  1.8941434292544892
# Efficiency =  0.4735358573136223

# %% [markdown]
# ### COMMENTO
# Quale è il vantaggio della parallelizzazione? Fare più statistica. Ogni nodo campiona in modo diverso i cammini, tramite mutazione e crossover e popolazione iniziale. Inoltre lo scambio aiuta i diversi nodi a non cadere in un minimo locale e non restare bloccati.
# Come mostrato dai grafici ho calcolato lo *speedup* relativo ed è risultato in un miglioramento della performance. (per arrivare allo stesso minimo però.. che potrebbe non essere quello globale)
