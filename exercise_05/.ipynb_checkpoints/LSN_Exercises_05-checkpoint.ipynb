# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 5</span>

# %% [markdown]
# In quantum physics a **wave function**, $\Psi$, is a mathematical description of the state of a quantum system. The wave function is a complex-valued probability amplitude, and the probabilities for the possible results of measurements made on the system can be derived from it.
#
# For now on, let's consider the simple case of a non-relativistic single particle, without spin, in three spatial dimensions. The state of such a particle is completely described by its wave function, $\Psi(\vec{r},t)$, where $\vec{r}$ is position and $t$ is time.
#
# For one spinless particle, if the wave function is interpreted as a probability amplitude, the square modulus of the wave function, $|\Psi(\vec{r},t)|^2$, is interpreted as the probability density that the particle is at $\vec{r}$ at time $t$. Once we have a probability density, we can use Monte Carlo ...
#
# #### Hydrogen atom
# The wave functions of the eigenstates of an electron in a Hydrogen atom (this is the only atom for which the Schroedinger equation has been solved exactly) are expressed in terms of spherical harmonics and generalized Laguerre polynomials. It is convenient to use spherical coordinates, and the wave function can be separated into functions of each coordinate:
#
# $$
# \Psi_{n,l,m}(r,\theta,\phi)=
# \sqrt{\left(\frac{2}{na_0}\right)^3 \frac{(n-l-1)!}{2n[(n+l)!]}}
# e^{-r/na_0}\left(\frac{2r}{na_0}\right)^l L_{n-l-1}^{2l+1}\left(\frac{2r}{na_0}\right)
# Y_l^m(\theta,\phi)
# $$
#
# where $a_0=4\pi\epsilon_0\hbar^2/m_e e^2=0.0529$ nm is the Bohr radius, $L_{n-l-1}^{2l+1}$ are the generalized Laguerre polynomials of degree $n-l-1$, $n=1,2,...$ is the principal quantum number, $l=0,1, ..., n-1$ the azimuthal quantum number, $m=-l, -l+1, ..., l-1, l$ the magnetic quantum number.
#
# For example, the ground state wave function is:
# $$
# \Psi_{1,0,0}(r,\theta,\phi)=
# \frac{a_0^{-3/2}}{\sqrt{\pi}} e^{-r/a_0}
# $$
# whereas one of the three $2p$ excited state is:
# $$
# \Psi_{2,1,0}(r,\theta,\phi)=
# \frac{a_0^{-5/2}}{8}\sqrt{\frac{2}{\pi}} r e^{-r/2a_0} \cos(\theta)
# $$
# <span style="color:blue">Expectation values for the radius turns out to be exactly:
# $$
# \left\langle r \right\rangle_{\Psi_{1,0,0}} = \frac{3}{2}a_0
# \quad
# \left\langle r \right\rangle_{\Psi_{2,1,0}} = 5 a_0
# $$
# </span>
#
#
# ### Exercise 05.1
#
#
# Use the Metropolis algorithm to sample $|\Psi_{1,0,0}(x,y,z)|^2$ and $|\Psi_{2,1,0}(x,y,z)|^2$ **in Cartesian coordinates** using an uniform transition probability $T(\vec{x}|\vec{y})$. Use the sampled positions to estimate $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ and $\left\langle r \right\rangle_{\Psi_{2,1,0}}$. As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# <span style="color:red">Show a picture of your estimations of $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ and $\left\langle r \right\rangle_{\Psi_{2,1,0}}$</span> and their uncertainties with a large number of *throws* $M$ (e.g. $M\ge 10^6$) as a function of the number of blocks, $N$</font>.
#
# - Use Bohr radius units, $a_0$ for distances
# - Choose the step of the uniform transition probability $T(\vec{x}|\vec{y})$ in order to obtain 50% of acceptance in both cases
# - Choose a reasonable starting point in the 3D space and equilibrate your sampling before to start measuring the radius. What do you observe when you start very far from the origin? if we start very far from the origin we will sample just one point, because all the moves will be rejected (also beacause my $\delta$ is not so big).
# - How large should be the number of Monte Carlo Metropolis steps in each block?
# - If you use a multivariate normal transition probability $T(\vec{x}|\vec{y})$, i.e. a Gaussian for each coordinate, your result for $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ and $\left\langle r \right\rangle_{\Psi_{2,1,0}}$ is equivalent? yes the result is equivalent.

# %% [markdown]
# ### ex
#
# Nella cartella *ex* è presente l'implementazione del codice relativo alla quinta esercitazione.
# Durante questa esercitazione abbiamo utilizzato **l'algoritmo di Metropolis** per campionare le distribuzioni di probabilità definite dal modulo quadro delle autofunzioni dello stato fondamentale e del primo stato eccitato dell'atomo idrogeno.  Ovvero $|\Psi_{1,0,0}(x,y,z)|^2$ and $|\Psi_{2,1,0}(x,y,z)|^2$ **in coordinate cartesiane**. In generale queste autofunzioni vengono espresse come $|\Psi_{n,l,m}(x,y,z)|^2$, dove $n,l,m$ sono i numeri quantici che caratterizzano lo stato del sistema quantistico (livello energetico, modulo momento angolare, componente z momento angolare).
# Questi moduli quadri definiscono una distribuzione di probabilità nello spazio $(x,y,z)$, per cui tramite loro si possono ricavare i valori medi $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ e $\left\langle r \right\rangle_{\Psi_{2,1,0}}$ campionando le posizioni nello spazio. Per campionare queste posizioni, e quindi concretamente valutare l'integrale $$\left\langle r \right\rangle_{\Psi_{n,l,m}} = \int_0^{2\pi} d\phi \int_0^\pi d\theta \sin(\theta)\int_0^{+\infty} r^2 dr |\Psi_{n,l,m}(\phi,\theta,r)|^2 r $$ (dove in questo caso ho scritto in coordinate sferiche gli argomenti dell'integrale per comodità, ma ricordo che questo esercizio è stato svolto utilizzando le coordinate cartesiane)
#
# Per poterlo fare mi sono avvalso, come scritto sopra, dell'algoritmo di Metropolis:
# 1. prima di tutto scegliere la probabilità di transizione $T(\vec{x_{new}}|\vec{x})$ per proporre una nuova mossa ($\vec x_{new}$) al sistema sapendo che si trova in $\vec x$ (quindi è un processo di Markow). Tale probabilità di transizione è stata implementata in due modi differenti:
#     - $T(\vec{x_{new}}|\vec{x})$ uniforme, ottenendo però un *acceptance rate* del $50\%$. Per fare questo ho utilizzato un $\delta$ pari a $a_0$ (raggio di Bohr), unità di misura del nostro sistema. (questa scelta è molto ragionevole, il sistema quantistico che stiamo considerando è l'atomo di idrogeno e il raggio dell'atomo è proprio dell'ordine di $a_0$).
#     - $T(\vec{x_{new}}|\vec{x})$ Gaussiana, ottenendo sempre un *acceptance rate* del $50\%$. Per fare questo ho utilizzato una $\sigma$ pari a $2a_0$ (raggio di Bohr). Valgono le stesse considerazioni fatte sopra
# 2. definita la probabilità di transizione si può iniziare a campionare. A questo punto entriamo nel cuore dell'algoritmo. Si propone una nuova mossa $\vec x_{new}$. Viene valutato il modulo quadro dell'autofunzione su questa nuova mossa e sulla mossa attuale, $|\Psi_{n,l,m}(\vec x_{new})|^2$,$|\Psi_{n,l,m}(\vec x)|^2$ e si estrapola il $min (1, \dfrac{|\Psi_{n,l,m}(\vec x_{new})|^2}{|\Psi_{n,l,m}(\vec x)|^2})$.
#     - compare il rapporto tra le probabilità valutate in punti diversi. Questo significa che non ci importa nemmeno che queste probabilità siano normalizzate.
#     - Inoltre teoricamente all'interno della scelta del minimo andrebbero poste anche le probabilità di transizione, il loro rapporto. Ma in questo caso $T(\vec{x_{new}}|\vec{x}) = T(\vec{x}|\vec{x_{new}})$ per come sono state scelte, per cui il loro rapporto è pari a $1$
# 3. viene generato un numero Random in modo uniforme in $[0,1]$ e se questo è minore del numero estrapolato nel punto 2 allora la mossa viene accettata. Da notare che se il rapporto $\dfrac{|\Psi_{n,l,m}(\vec x_{new})|^2}{|\Psi_{n,l,m}(\vec x)|^2} > 1$ allora la mossa viene accettata sicuramente.
#
# Questo procedimento viene eseguito per un numero di step definito all'inizio della simulazione. Nel mio caso ho scelto $M = 10^6$. Alla fine del campionamento viene eseguita la solita analisi dati con il metodo blocking.
#
# **NEL CODICE**: il procedimento sopra descritto viene interamente eseguito da un'unica funzione chiamata una sola volta nel main. Tale funzione prende come argomento:
# - generatore di numeri casuali
# - numero totale di iterazioni
# - numero di blocchi per il blocking
# - delta per la probabilità di transizine
#
# Oltre che valutare il valore medio di $r$ durante l'esecuzione del codice è stato scelto anche si salvare su file le posizioni generate e accettate ad ogni iterazione. Questo per monitorare che si stia effettivamente distribuendo in modo corretto i punti nello spazio $3D$ (e anche per vedere la forma dell'orbitale). Per cui di seguito vengono anche mostrati questi risultati.
# Inoltre ho deciso di calcolare la funzione di auto-correlazione di questi punti, per determinare la lunghezza di correlazione e comprendere meglio quanto devono essere grandi i blocchi per l'analisi dati svolta con il metodo blocking.

# %% [markdown]
# ### PRIMA PARTE
#
# Ci sono due domande da porsi prima di iniziare:
# - da che punto partire per iniziare a campionare
# - che $\delta$ scegliere per la probabilità di transizione $T(\vec{x_{new}}|\vec{x})$
#
# Di seguito mostro dei tentativi andati non a buon fine, cercando di rispondere a queste domande.

# %% [markdown]
# #### Choosing a different starting point instead of the the origin

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy.optimize import curve_fit
matplotlib.rcParams['text.usetex'] = True

fig = plt.figure(figsize=(15,5))

X = np.loadtxt("tentativi/campionamenti100farorigin.txt",usecols=(0)) 
Y = np.loadtxt("tentativi/campionamenti100farorigin.txt",usecols=(1))
Z = np.loadtxt("tentativi/campionamenti100farorigin.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{1,0,0}}|^2$, $T(x^{new}|x^{old})$ uniform',fontsize=30)
ax.view_init(10,30)

X = np.loadtxt("tentativi/campionamenti210farorigin.txt",usecols=(0))  
Y = np.loadtxt("tentativi/campionamenti210farorigin.txt",usecols=(1))
Z = np.loadtxt("tentativi/campionamenti210farorigin.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{2,1,0}}|^2$, $T(x^{new}|x^{old})$ uniform',fontsize=30)
ax.view_init(10,30)

plt.show()

# %% [markdown]
# #### COMMENTO
# scegliendo come punto di partenza un vettore lontano dall'origine non si riesce a campionare tutto lo spazio, ovvero ogni mossa proposta rischia di essere rifiutata e si resta sempre nello stesso punto. Come ho mostrato nei grafici.
# In questo caso $x_0 = (1.8904e+10 \cdot a_0,1.8904e+10\cdot a_0,1.8904e+10\cdot a_0)$
# I punti iniziali scelti per campionare sono stati:
# - per $|{\Psi_{1,0,0}}|^2$ --> $x_0 = (0,0,0)$
# - per $|{\Psi_{2,1,0}}|^2$ --> $x_0 = (\frac{a_0}{2},\frac{a_0}{2},\frac{a_0}{2})$

# %% [markdown]
# #### Choosing a small $\delta$

# %%
fig = plt.figure(figsize=(15,5))

X = np.loadtxt("tentativi/campionamenti100smalldelta.txt",usecols=(0)) 
Y = np.loadtxt("tentativi/campionamenti100smalldelta.txt",usecols=(1))
Z = np.loadtxt("tentativi/campionamenti100smalldelta.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{1,0,0}}|^2$, $T(x^{new}|x^{old})$ uniform',fontsize=30)
ax.view_init(10,30)

X = np.loadtxt("tentativi/campionamenti210smalldelta.txt",usecols=(0))  
Y = np.loadtxt("tentativi/campionamenti210smalldelta.txt",usecols=(1))
Z = np.loadtxt("tentativi/campionamenti210smalldelta.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{2,1,0}}|^2$, $T(x^{new}|x^{old})$ uniform',fontsize=30)
ax.view_init(10,30)

plt.show()

# %% [markdown]
# #### COMMENTO
#
# Non basta ovviamente scegliere dei buoni punti di partenza, ma è necessario anche scegliere una $\delta$ ragionevole per la probabilità di transizione. Scegliendo una delta troppo piccola non si riesce a campionare tutto lo spazio, ma solo l'intorno di tale $\delta$, come mostrato nelle figure.
# Come già detto all'inizio del notebook le scelte finali sono state:
# - per probabilità uniforme $\delta = a_0$
# - per probabilità gaussiana $\sigma = 2 a_0$

# %% [markdown]
# ### Doing the right things, M = $10^6$

# %%
def f1(x,a,l):  # defining the fitting function
    return a * np.exp(-x/l)

N=100

fig = plt.figure(figsize=(15,5))

X = np.loadtxt("campionamenti100.txt",usecols=(0)) 
Y = np.loadtxt("campionamenti100.txt",usecols=(1))
Z = np.loadtxt("campionamenti100.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{1,0,0}}|^2$, $T(x^{new}|x^{old})$ uniform',fontsize=30)
ax.view_init(10,30)

X = np.loadtxt("campionamenti210.txt",usecols=(0))  
Y = np.loadtxt("campionamenti210.txt",usecols=(1))
Z = np.loadtxt("campionamenti210.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{2,1,0}}|^2$, $T(x^{new}|x^{old})$ uniform',fontsize=30)
ax.view_init(10,30)

r100 = np.loadtxt("r100all.txt",usecols=(0), delimiter=' ', unpack='true')
r210 = np.loadtxt("r210all.txt",usecols=(0), delimiter=' ', unpack='true')
Av_r100 = np.average(r100)
Av_r210 = np.average(r210)
r100_base = r100-Av_r100
r210_base = r210-Av_r210

################ AUTO-CORRELATION ##################################
                         
fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15, 5))
xir = axs[0].acorr(r100_base[1000:],normed=True,maxlags=60)
x = xir[0][60:]
p_opt, p_cov = curve_fit(f1,x,xir[1][60:])#,bounds=([0,1],[2,3]))
f_fit = f1(x,p_opt[0],p_opt[1])
axs[0].plot(x,f_fit,color="r")
axs[0].set_title(r"Auto-correlation function, $|\Psi_{1,0,0}|^2$",fontsize=20)
print("optimized parameters [a,l] =",p_opt,", parameters uncertainty =",np.sqrt(np.diagonal(p_cov)))
yir = axs[1].acorr(r210_base[1000:],normed=True,maxlags=60)
x = yir[0][60:]
p_opt, p_cov = curve_fit(f1,x,yir[1][60:])#,bounds=([0,1],[2,3]))
f_fit = f1(x,p_opt[0],p_opt[1])
axs[1].plot(x,f_fit,color="r")
axs[1].set_title(r"Auto-correlation function, $|\Psi_{2,1,0}|^2$",fontsize=20)
print("optimized parameters [a,l] =",p_opt,", parameters uncertainty =",np.sqrt(np.diagonal(p_cov)))

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15, 5))
x = np.arange(N)
y = np.zeros(N)
sum_prog,err_prog = np.loadtxt("r100.txt",usecols=(0,1), delimiter=' ', unpack='true')
axs[0].errorbar(x,sum_prog,yerr=err_prog,color='b',ecolor='g')
axs[0].set_ylabel(r"$\frac{<r>_{1,0,0}}{a_0}-1.5$",fontsize=15)
axs[0].set_xlabel("number of blocks")
axs[0].plot(x,y,color='black')
axs[0].set_title(r"Data blocking $<r>$, $|\Psi_{1,0,0}|^2$",fontsize=20)

sum_prog,err_prog = np.loadtxt("r210.txt",usecols=(0,1), delimiter=' ', unpack='true')
axs[1].errorbar(x,sum_prog,yerr=err_prog,color='b',ecolor='g')
axs[1].set_ylabel(r"$\frac{<r>_{2,1,0}}{a_0}-5$",fontsize=15)
axs[1].set_xlabel("number of blocks")
axs[1].plot(x,y,color='black')
axs[1].set_title(r"Data blocking $<r>$, $|\Psi_{2,1,0}|^2$",fontsize=20)

plt.show()
# Out:
# optimized parameters [a,l] = [ 0.97085018 14.08552228] , parameters uncertainty = [0.00454419 0.09697775]
# optimized parameters [a,l] = [ 0.98036288 45.87069378] , parameters uncertainty = [0.00237214 0.21837935]

# %% [markdown]
# ### FIT CON FUNZIONE DI AUTOCORRELAZIONE:
# - ho fittato la funzione di autocorrelazione con una funzione del tipo $a \cdot exp(\frac{-x}{l})$, dove quindi $l$ rappresenta la lunghezza di correlazione
# - la lunghezza di correlazione mi dice quanto devono essere grandi i blocchi per non avere misure correlate tra loro
# - $l_{1,0,0} \approx 14$
# - $l_{2,1,0} \approx 46$

# %%
fig = plt.figure(figsize=(15,5))

X = np.loadtxt("campionamenti100gauss.txt",usecols=(0)) 
Y = np.loadtxt("campionamenti100gauss.txt",usecols=(1))
Z = np.loadtxt("campionamenti100gauss.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{1,0,0}}|^2$, $T(x^{new}|x^{old})$ gaussian',fontsize=30)
ax.view_init(10,30)

X = np.loadtxt("campionamenti210gauss.txt",usecols=(0))  
Y = np.loadtxt("campionamenti210gauss.txt",usecols=(1))
Z = np.loadtxt("campionamenti210gauss.txt",usecols=(2))

ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.scatter(X, Y, Z, c=Z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title(r'$|{\Psi_{2,1,0}}|^2$, $T(x^{new}|x^{old})$ gaussian',fontsize=30)
ax.view_init(10,30)

r100 = np.loadtxt("r100allgauss.txt",usecols=(0), delimiter=' ', unpack='true')
r210 = np.loadtxt("r210allgauss.txt",usecols=(0), delimiter=' ', unpack='true')
Av_r100 = np.average(r100)
Av_r210 = np.average(r210)
r100_base = r100-Av_r100
r210_base = r210-Av_r210

################ AUTO-CORRELATION ##################################
                         
fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15, 5))
xir = axs[0].acorr(r100_base[1000:],normed=True,maxlags=60)
x = xir[0][60:]
p_opt, p_cov = curve_fit(f1,x,xir[1][60:])#,bounds=([0,1],[2,3]))
f_fit = f1(x,p_opt[0],p_opt[1])
axs[0].plot(x,f_fit,color="r")
axs[0].set_title(r"Auto-correlation function, $|\Psi_{1,0,0}|^2$",fontsize=20)
print("optimized parameters [a,l] =",p_opt,", parameters uncertainty =",np.sqrt(np.diagonal(p_cov)))
yir = axs[1].acorr(r210_base[1000:],normed=True,maxlags=60)
x = yir[0][60:]
p_opt, p_cov = curve_fit(f1,x,yir[1][60:])#,bounds=([0,1],[2,3]))
f_fit = f1(x,p_opt[0],p_opt[1])
axs[1].plot(x,f_fit,color="r")
axs[1].set_title(r"Auto-correlation function, $|\Psi_{2,1,0}|^2$",fontsize=20)
print("optimized parameters [a,l] =",p_opt,", parameters uncertainty =",np.sqrt(np.diagonal(p_cov)))

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15, 5))
x = np.arange(N)
y = np.zeros(N)
sum_prog,err_prog = np.loadtxt("r100gauss.txt",usecols=(0,1), delimiter=' ', unpack='true')
axs[0].errorbar(x,sum_prog,yerr=err_prog,color='b',ecolor='g')
axs[0].set_ylabel(r"$\frac{<r>_{1,0,0}}{a_0}-1.5$",fontsize=15)
axs[0].set_xlabel("number of blocks")
axs[0].plot(x,y,color='black')
axs[0].set_title(r"Data blocking $<r>$, $|\Psi_{1,0,0}|^2$",fontsize=20)

sum_prog,err_prog = np.loadtxt("r210gauss.txt",usecols=(0,1), delimiter=' ', unpack='true')
axs[1].errorbar(x,sum_prog,yerr=err_prog,color='b',ecolor='g')
axs[1].set_ylabel(r"$\frac{<r>_{2,1,0}}{a_0}-5$",fontsize=15)
axs[1].set_xlabel("number of blocks")
axs[1].plot(x,y,color='black')
axs[1].set_title(r"Data blocking $<r>$, $|\Psi_{2,1,0}|^2$",fontsize=20)

plt.show()
# Out:
# optimized parameters [a,l] = [ 0.95611401 15.89938364] , parameters uncertainty = [0.00754509 0.18473092]
# optimized parameters [a,l] = [0.97627098 9.86549056] , parameters uncertainty = [0.00323297 0.0485731 ]

# %% [markdown]
# ### FIT CON FUNZIONE DI AUTOCORRELAZIONE:
# - ho fittato la funzione di autocorrelazione con una funzione del tipo $a \cdot exp(\frac{-x}{l})$, dove quindi $l$ rappresenta la lunghezza di correlazione
# - la lunghezza di correlazione mi dice quanto devono essere grandi i blocchi per non avere misure correlate tra loro
# - $l_{1,0,0} \approx 16$
# - $l_{2,1,0} \approx 10$

# %% [markdown]
# Come mostrato nei grafici ho trovato la lunghezza di correlazione facendo un fit con un esponenziale e ricavando una stima del numero di valori da avere in ogni blocco per non avere correlazioni tra blocchi.
# Successivamente ho mostrasto i risultati ottenuti con il metodo blocking (traslando in 0 sulle y)

# %% [markdown]
# Ho campionato $10^6$ e ho usato $100$ blocchi. (non erano necessari così tanti campionamenti per blocco)
# I grafici mostrano i risultati ottenuti con il metodo blocking e per tutti i casi mostrati il risultato è compatibile (entro una $\sigma$) con il valore vero. Inoltre ho notato che l'errore ricavato tramite il campionamento con probabilità gaussiana è minore rispetto a quello ricavato con il campionamento uniforme.
