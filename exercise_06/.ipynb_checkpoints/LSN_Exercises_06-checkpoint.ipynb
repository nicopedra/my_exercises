# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 06.1</span>

# %% [markdown]
# Complete the C++ code to simulate 1D Ising model (It is available on the Ariel web site of this Laboratory) with
# - the Metropolis sampling algorithm and
# - the Gibbs sampling algorithm
#
# to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$,
# adding also the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# - <span style="color:red">Show pictures of your estimations of $U(N,T)$, $C(N,T)$, $\chi(N,T)$, $M(N,T,h=0.02)$ and their uncertainties</span> obtained with a large number of *MC steps* (e.g. $M\ge 10^5$) compared with the exact curves. In the same picture show your results obtained with both sampling methods, Metropolis and Gibbs.
#
# A Monte Carlo step will consist in trying to flip one time all the spins of the system. Do not forget to equilibrate your simulations and to use blocking average with blocks large enough.

# %% [markdown]
# ### ISING_1D
#
# Nella cartella ISING_1D è presente l'implementazione del codice relativo alla sesta esercitazione.
# Durante questa esercitazione abbiamo simulato tramite una simulazione di tipo MonteCarlo (**MC**) un modello di Ising 1D, composto da 50 spin.
# Simulare un sistema tramite metodo MC significa fisicamente porsi in un insieme statistico canonico, ovvero a temperatura fissata e quindi all'equilibrio termodinamico con l'esterno (il sistema fisico è all'equilibrio termico con l'ambiente, con cui può scambiare energia ma non materia), campionando lo spazio delle configurazioni con la distribuzione di Boltzmann.
# Per campionare il sistema (concretamenta accettare un flip di spin oppure no) mi sono ricondotto, come richiesto, a due modalità:
# 1. Metropolis:
#     - viene proposto il flip di uno spin (s->-s).
#     - Viene calcolata l'energia per spin flippato $E_{new} = U(-s)$ e per spin non flippato $E_{old} = U(s)$.
#     - Si applica l'algoritmo di Metropolis estrapolando il $\min (1., e ^{-\beta (E_{new}-E_{old})})$
#     - viene generato un numero random in modo uniforme in $[0,1]$ e paragonato con il numero estrapolato con Metropolis. Se minore allora si accetta il flip, altrimento no.
# 2. Gibbs:
#     - viene proposto il flip di uno spin (s->-s).
#     - Viene calcolata l'energia per spin flippato $E_{new} = U(-s)$ e per spin non flippato $E_{old} = U(s)$.
#     - Si applica l'algoritmo di Gibbs ricavando $p = \dfrac {1.}{1+e ^{-\beta (E_{new}-E_{old})} }$
#     - viene generato un numero random in modo uniforme in $[0,1]$, se minore di $p$ allora si accetta il flip, altrimento no.
#
# Viene compiuto un ciclo sul numero di spin e viene scelto in modo casuale un spin da flippare.
# Per scegliere se campionare usando Gibbs o Metropolis semplicemente viene dato in input (tramite file) un paramtro $\texttt{metro}$ che se posto $=1$ allora il codice esegue campionamento Metropolis, altrimenti Gibbs.
#
# #### PARAMETRI
# I parametri necessari vengono letti dal file *input.dat*, oppure dati da linea di comando
# 1. da file:
#     - numero di spin ($50$)
#     - $\texttt{J}$
#     - $\texttt{h}$
#     - $\texttt{metro}$
#     - numero di blocchi
#     - numero di step per blocco
# 2. da terminale:
#     - temperatura
#     - parametro restart (per assegnare alla configurazione iniziale l'ultima assunta nella precedente simulazione)
#
# Per comprendere chi sono i parametri $\texttt{J}$  e $\texttt{h}$ basta ricordare la forma dell'Hamiltoniana del nostro sistema: $$H = -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1}) $$
# Per cui $\texttt{J}$ è il peso dell'interazione di scambio (uguale per tutti e posta a 1), e $\texttt{h}$ il campo magnetico esterno.

# %% [markdown]
# Un'ulteriore questione da tenere a mente sono le condizioni periodiche al contorno, il nostro sistema può essere facilmente visualizzato nella figura seguente.
# <img src="PBCising.png" width="300">

# %% [markdown]
# #### CODICE
# Nel codice la funzione che propone una mossa si chiama $\texttt{move}$.
# Inoltre viene chiamata anche un'altra funzione $\texttt{measure}$ che invece misura le proprietà fisiche del sistema:
# - Energia interna per sping $\frac{U}{N}$
# - magnetizzazione $M$
# - calore specifico $C$
# - suscettività magnetica $\chi$
#
# Per l'analisi dati viene sempre utilizzato il metodo blocking.
# Nella prima parte dell'esercitazione mi sono occupato di studiare l'equilibrazione del sistema. Osservando che dopo pochi step il campionamento è già equilibrato (come mostrato nei grafici). Ho mostrato questo sia osservando i valori istantanei dell'Energia, sia mostrando l'analisi dati a blocchi per una singola simulazione a temperatura fissata.

# %% [markdown]
# ### EQUILIBRAZIONE
# Inizio attaccando tra loro 3 simulazioni misurando 100 valori instantanei di U/N. La prima simulazione parte da una configurazione random mentre le altre dall'ultima configurazione assunta dalla simulazione precedente.
# In questo modo si vede chiaramente che al sistema bastano pochi passi per stabilizzarsi (fluttazioni del valore di Energia attorno a un certo valore medio)

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 1
model = "Gibbs","Metropolis"
fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15, 5))

for i in range(2):
    axs[i].set_title("Monte Carlo, "+model[i]+", Equilibration (T=1,h=0)",fontsize=15)
    axs[i].set_ylabel("U/N (instantaneous values)")
    axs[i].set_xlabel("throwns")
    y = np.loadtxt(model[i]+"/equilibration/inst_ene.out",usecols=(0),unpack='true')
    x = np.arange(len(y))
    axs[i].plot(x,y)

plt.show()

# %%
T = 1

name = "output.ene.0","output.hc.0","output.mag.0","output.chi.0"
Lab = "U/N","C","$M_{h=0.02}$","$\chi$"

fig,axs = plt.subplots(nrows=2,ncols=2,figsize=(20, 20))

axs[0][0].set_title("Monte Carlo, Gibbs sampling, Equilibration (T=1)",fontsize=25)
for i in range(2):
    for j in range(2):
        x = np.loadtxt("Gibbs/equilibration/"+name[i+2*j],usecols=(0),unpack='true')
        sum_prog,err_prog = np.loadtxt("Gibbs/equilibration/"+name[i+2*j],usecols=(2,3),unpack='true')
        axs[i][j].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
        axs[i][j].set_xlabel("Nblocks",fontsize=15)
        axs[i][j].set_ylabel(Lab[i+2*j],fontsize=15)


plt.show()

# %%
fig,axs = plt.subplots(nrows=2,ncols=2,figsize=(20, 20))


axs[0][0].set_title("Monte Carlo, Metropolis sampling, Equilibration (T=1)",fontsize=25)
for i in range(2):
    for j in range(2):
        x = np.loadtxt("Metropolis/equilibration/"+name[i+2*j],usecols=(0),unpack='true')
        sum_prog,err_prog = np.loadtxt("Metropolis/equilibration/"+name[i+2*j],usecols=(2,3),unpack='true')
        axs[i][j].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
        axs[i][j].set_xlabel("Nblocks",fontsize=15)
        axs[i][j].set_ylabel(Lab[i+2*j],fontsize=15)
plt.show()

# %% [markdown]
# ### $2^a$ parte
# Nella seconda parte viene richiesto di plottare in funzione della temperatura i valori delle proprietà fisiche elencate precedentemente.
# Per farlo è stato scritto uno $\texttt{script}$ chiamato $\texttt{simulazione.sh}$ che esegue diverse simulazioni a temperature differenti nell'intervallo $[0.2,3]$ (a step di $0.1$).
# Per ogni simulazione viene eseguito il metodo a blocchi per l'analisi dati estrapolando il valore finale della proprietà analizzata con il suo errore, per poi plottarlo.
# Tutti i risultati sono stati confrontati con la soluzione analitica sovrapponendo i grafici, ottenendo ottimi risultati.
# **Nota** : non è ancora stato specificato ma stiamo lavorando in unità di $k_B$ costante di Boltzmann, e in unità di $J$, per l'energia, cioè abbiamo posto la costante di Boltzmann $k_B = 1$ e $J = 1$
#
# **Analisi dati** :
# - numero di blocchi $50$
# - numero di step per blocco $1000$
#
# **temperature** :
# - $[0.2,3.0]$ a passi di $0.1$

# %% [markdown]
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following I will assume units such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(20, 10))

axs[0].plot(T, e)
axs[0].set_title('Ising 1D, internal energy (h=0). \n Overlap of analytical solution and \n Monte Carlo Simulation with Gibbs sampling',fontsize=20)
axs[0].set_xlabel('T',fontsize=15)
axs[0].set_ylabel('U/N',fontsize=15)

x = np.loadtxt("Gibbs/output.ene.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Gibbs/output.ene.final",usecols=(1,2),unpack='true')
axs[0].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[0].legend(["analytical","Monte Carlo"])


axs[1].plot(T, e)
axs[1].set_title('Ising 1D, internal energy.\n Overlap of analytical solution and \n Monte Carlo Simulation with Metropolis',fontsize=20)
axs[1].set_xlabel('T',fontsize=15)
axs[1].set_ylabel('U/N',fontsize=15)

x = np.loadtxt("Metropolis/output.ene.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Metropolis/output.ene.final",usecols=(1,2),unpack='true')
axs[1].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[1].legend(["analytical","Monte Carlo"])

plt.show()

# %% [markdown]
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$

# %%
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(20, 10))

axs[0].plot(T, heat)
axs[0].set_title('Ising 1D, Heat capacity (h=0). \n Overlap of analytical solution and \n Monte Carlo Simulation with Gibbs sampling',fontsize=20)
axs[0].set_xlabel('T',fontsize=15)
axs[0].set_ylabel('C',fontsize=15)

x = np.loadtxt("Gibbs/output.hc.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Gibbs/output.hc.final",usecols=(1,2),unpack='true')
axs[0].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[0].legend(["analytical","Monte Carlo"])


axs[1].plot(T, heat)
axs[1].set_title('Ising 1D, Heat capacity.\n Overlap of analytical solution and \n Monte Carlo Simulation with Metropolis',fontsize=20)
axs[1].set_xlabel('T',fontsize=15)
axs[1].set_ylabel('C',fontsize=15)

x = np.loadtxt("Metropolis/output.hc.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Metropolis/output.hc.final",usecols=(1,2),unpack='true')
axs[1].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[1].legend(["analytical","Monte Carlo"])

plt.show()

# %% [markdown]
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$

# %%
h=0.02 #external field
b = 1/T

l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(20, 10))

axs[0].plot(T, M)
axs[0].set_title('Ising 1D, magnetization M with h =0.02. \n Overlap of analytical solution and \n Monte Carlo Simulation with Gibbs sampling',fontsize=20)
axs[0].set_xlabel('T',fontsize=15)
axs[0].set_ylabel('$M$',fontsize=15)

x = np.loadtxt("Gibbs/output.mag.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Gibbs/output.mag.final",usecols=(1,2),unpack='true')
axs[0].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[0].legend(["analytical","Monte Carlo"])


axs[1].plot(T, M)
axs[1].set_title('Ising 1D, magnetization M with h =0.02.\n Overlap of analytical solution and \n Monte Carlo Simulation with Metropolis',fontsize=20)
axs[1].set_xlabel('T',fontsize=15)
axs[1].set_ylabel('C',fontsize=15)

x = np.loadtxt("Metropolis/output.mag.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Metropolis/output.mag.final",usecols=(1,2),unpack='true')
axs[1].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[1].legend(["analytical","Monte Carlo"])

plt.show()

# %% [markdown]
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(20, 10))

axs[0].plot(T, X)
axs[0].set_title('Ising 1D, Susceptibility (h=0). \n Overlap of analytical solution and \n Monte Carlo Simulation with Gibbs sampling',fontsize=20)
axs[0].set_xlabel('T',fontsize=15)
axs[0].set_ylabel('$\chi$',fontsize=15)

x = np.loadtxt("Gibbs/output.chi.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Gibbs/output.chi.final",usecols=(1,2),unpack='true')
axs[0].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[0].legend(["analytical","Monte Carlo"])


axs[1].plot(T, X)
axs[1].set_title('Ising 1D, Susceptibility.\n Overlap of analytical solution and \n Monte Carlo Simulation with Metropolis',fontsize=20)
axs[1].set_xlabel('T',fontsize=15)
axs[1].set_ylabel('$\chi$',fontsize=15)

x = np.loadtxt("Metropolis/output.chi.final",usecols=(0),unpack='true')
sum_prog,err_prog = np.loadtxt("Metropolis/output.chi.final",usecols=(1,2),unpack='true')
axs[1].errorbar(x,sum_prog,yerr=err_prog,color='r',ecolor='b')
axs[1].legend(["analytical","Monte Carlo"])


plt.show()
